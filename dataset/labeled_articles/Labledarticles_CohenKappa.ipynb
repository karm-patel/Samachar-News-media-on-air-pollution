# %%
import pandas as pd

# %%
df = pd.read_csv("AQrelated_sampling_200articles_kappa_score.csv")
df
# Out:
#      Unnamed: 0  media        date  A1  A2  agreement \n(K & R)  \
# 0             0  Hindu  2019-03-17   1   1                    1
# 1             1    TOI  2017-02-14   1   1                    1
# 2             2    TOI  2016-12-01   1   0                    0
# 3             3    TOI  2011-11-21   1   1                    1
# 4             4    TOI  2018-08-28   1   1                    1
# ..          ...    ...         ...  ..  ..                  ...
# 195         195    TOI  2013-12-01   1   1                    1
# 196         196    TOI  2013-12-17   1   1                    1
# 197         197    TOI  2016-11-27   1   1                    1
# 198         198    TOI  2010-11-13   1   1                    1
# 199         199  Hindu  2016-11-17   1   1                    1
#
#      AQ related\nBoth 1                                                url  \
# 0                     1  https://www.thehindu.com/news/cities/Kochi/no-...
# ...

# %%
#Cohen kappa
df["agreement \n(K & R)"].sum()/len(df)
# Out:
# 0.94

# %%
#AQ Related labeld by both author
df["AQ related\nBoth 1"].sum()
# Out:
# 182
