# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 100)
from pandas import json_normalize
import numpy as np
import os
import csv
import multiprocessing as mp
import re
from datetime import datetime
# import helper as h
# import AQDataHelper as aqh
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
import matplotlib
import geopy


import warnings
warnings.filterwarnings("ignore")

# %%
df_articles = pd.read_csv("../dataset/News_articles_dataset/News_articles_dataset.csv.gz")
df_articles
# Out:
#        media        date  \
# 0        TOI  2010-01-01
# 1        TOI  2010-01-02
# 2        TOI  2010-01-09
# 3        TOI  2010-01-11
# 4        TOI  2010-01-13
# ...      ...         ...
# 17369  Hindu  2021-05-16
# 17370  Hindu  2021-05-24
# 17371  Hindu  2021-05-25
# 17372  Hindu  2021-05-28
# 17373  Hindu  2021-05-30
#
#                                                                                                        url  \
# 0      http://timesofindia.indiatimes.com//city/mumbai/Mumbai-celebrates-a-cool-New-Years-Eve-at-13-4C/...
# 1      http://timesofindia.indiatimes.com//city/lucknow/Dense-fog-leads-to-tripping-of-power-lines/arti...
# 2      http://timesofindia.indiatimes.com//city/chennai/City-has-high-levels-of-smog-forming-ozone/arti...
# 3      http://timesofindia.indiatimes.com//city/jaipur/Woman-four-kids-in-hospital-after-inhaling-smoke...
# 4      http://timesofindia.indiatimes.com//city/chennai/Pollution-high-on-Bhogi-eve-Study/articleshow/5...
# ...                                                                                                    ...
# 17369  https://www.thehindu.com/news/national/andhra-pradesh/naval-dockyard-teams-repair-two-oxygen-pla...
# 17370  https://www.thehindu.com/news/national/kerala/greens-call-for-a-relook-into-silverline-implement...
# 17371  https://www.thehindu.com/news/national/karnataka/cftris-ozone-based-air-disinfection-system-to-c...
# 17372  https://www.thehindu.com/news/national/ngt-stays-green-nod-for-ntpcs-karimnagar-plant/article346...
# 17373  https://www.thehindu.com/news/national/kerala/create-forests-to-stop-global-warming-says-ministe...
#
#                                                                          heading  \
# 0                             Mumbai celebrates a cool New Year's Eve at 13.4फ्C
# 1                                     Dense fog leads to tripping of power lines
# 2                                     City has high levels of smog-forming ozone
# 3                              Woman, four kids in hospital after inhaling smoke
# 4                                             Pollution high on Bhogi eve: Study
# ...                                                                          ...
# 17369  Naval Dockyard teams repair two oxygen plants in Nellore and Srikalahasti
# 17370                   Greens call for a relook into SilverLine implementation
# 17371  CFTRI’s ozone-based air disinfection system to combat droplet infections
# 17372                            NGT stays green nod for NTPC’s Karimnagar plant
# 17373                      Create forests to stop global warming, says Minister
#
#                                                                                                    content  \
# 0      MUMBAI: The city witnessed its lowest temperature of the season on New Year ’s Eve when the merc...
# 1      LUCKNOW: The UP Power Corporation Limited is keeping its fingers crossed for Saturday with the s...
# 2      CHENNAI: Dangerous levels of ground-level ozone that causes respiratory ailments could be envelo...
# 3      JAIPUR: A woman and her four kids were admitted to a city hospital in a serious condition after ...
# 4      CHENNAI: By the time you get to read this, the Bhogi pollutants may have enveloped the city, but...
# ...                                                                                                    ...
# 17369  Oxygen supply gets a big boost with this in the State during the pandemic\n\nTeams from the Nava...
# 17370  The Kerala Paristhithi Aikya Vedi, a forum of environmentalists, has urged Chief Minister Pinara...
# 17371  The CSIR-Central Food Technological Research Institute (CFTRI) in Mysuru has come up with an ozo...
# 17372  Environmental Clearance put on hold for seven months, bench calls for fresh appraisal.\n\nThe so...
# 17373  Minister for Local Self-Governments and Excise M.V. Govindan has called for a conscious effort t...
#
#                                            other.author  \
# 0                         TNN /  Jan 1, 2010, 01:47 IST
# 1                         TNN /  Jan 2, 2010, 06:40 IST
# 2       Bhama Devi Ravi / TNN /  Jan 9, 2010, 00:37 IST
# 3                        TNN /  Jan 11, 2010, 01:56 IST
# 4      Bhama Devi Ravi / TNN /  Jan 13, 2010, 04:23 IST
# ...                                                 ...
# 17369                              SpecialCorrespondent
# 17370                              SpecialCorrespondent
# 17371                                        LaiqhAKhan
# 17372                                         T.K.Rohit
# 17373                                     StaffReporter
#
#                                                                                            other.top_image  \
# 0      https://static.toiimg.com/thumb/msid-47529300,width-1070,height-580,imgsize-110164,resizemode-75...
# 1      https://static.toiimg.com/thumb/msid-47529300,width-1070,height-580,imgsize-110164,resizemode-75...
# 2      https://static.toiimg.com/thumb/msid-47529300,width-1070,height-580,imgsize-110164,resizemode-75...
# 3      https://static.toiimg.com/thumb/msid-47529300,width-1070,height-580,imgsize-110164,resizemode-75...
# 4      https://static.toiimg.com/thumb/msid-47529300,width-1070,height-580,imgsize-110164,resizemode-75...
# ...                                                                                                    ...
# 17369  https://www.thehindu.com/news/national/andhra-pradesh/fvjzld/article34572702.ece/ALTERNATES/LAND...
# 17370                                  https://www.thehindu.com/static/theme/default/base/img/og-image.jpg
# 17371  https://www.thehindu.com/sci-tech/science/wsmdd0/article33283019.ece/ALTERNATES/LANDSCAPE_615/CF...
# 17372  https://www.thehindu.com/news/cities/Hyderabad/article23578273.ece/ALTERNATES/LANDSCAPE_615/17HY...
# 17373                                  https://www.thehindu.com/static/theme/default/base/img/og-image.jpg
#
#        other.category                city    year           state  \
# 0                 NaN              mumbai  2010.0     maharashtra
# 1                 NaN             lucknow  2010.0   uttar pradesh
# 2                 NaN             chennai  2010.0      tamil nadu
# 3                 NaN              jaipur  2010.0       rajasthan
# 4                 NaN             chennai  2010.0      tamil nadu
# ...               ...                 ...     ...             ...
# 17369  andhra pradesh       visakhapatnam     NaN  andhra pradesh
# 17370          kerala  thiruvananthapuram     NaN          kerala
# 17371       karnataka              mysuru     NaN       karnataka
# 17372        national             chennai     NaN      tamil nadu
# 17373          kerala              kannur     NaN          kerala
#
#                  district  \
# 0         mumbai suburban
# 1                 lucknow
# 2                 chennai
# 3                  jaipur
# 4                 chennai
# ...                   ...
# 17369       visakhapatnam
# 17370  thiruvananthapuram
# 17371              mysuru
# 17372             chennai
# 17373              kannur
#
#                                                                       matches
# 0                                                               {'smog': 3.0}
# 1                                                     {'air pollutants': 2.0}
# 2                                                 {'ozone': 9.0, 'smog': 4.0}
# 3                                                    {'carbon monoxide': 1.0}
# 4      {'air quality': 1.0, 'carbon monoxide': 1.0, 'ozone': 1.0, 'so2': 1.0}
# ...                                                                       ...
# 17369                                                {'carbon monoxide': 2.0}
# 17370                                                  {'air pollution': 1.0}
# 17371                                                          {'ozone': 9.0}
# 17372                                                    {'air quality': 1.0}
# 17373                                                  {'air pollution': 1.0}
#
# [17374 rows x 13 columns]

# %%
#load PM2.5 data 2010-2019 (cpcb)
root_path = "../PMdataset/"
df_daily_city_stn = pd.read_csv(root_path+"pm2.5_allcities_groupby_date_city_station_2010_19.csv",index_col=0)
df_daily_city = pd.read_csv(root_path+"pm2.5_allcities_groupby_date_city_2010_19.csv",index_col=0)
#df_daily_city = df_daily_city.groupby(["From Date","city"]).mean().reset_index()
df_daily_city
# Out:
#         Unnamed: 0   From Date           city        WS          WD  Gust  \
# 0                0  2010-01-01           Agra       NaN         NaN   NaN
# 1                1  2010-01-01      Ahmedabad       NaN         NaN   NaN
# 2                2  2010-01-01        Ambala        NaN         NaN   NaN
# 3                3  2010-01-01     Ankleshwar       NaN         NaN   NaN
# 4                4  2010-01-01   Bahadurgarh        NaN         NaN   NaN
# ...            ...         ...            ...       ...         ...   ...
# 202192      202192  2019-04-30        Udaipur  1.017579  253.649263   NaN
# 202193      202193  2019-04-30         Ujjain  4.636842  255.042105   NaN
# 202194      202194  2019-04-30       Varanasi  0.801053  180.757895   NaN
# 202195      202195  2019-04-30     Vijayawada  0.519041  221.018904   NaN
# 202196      202196  2019-04-30  Visakhapatnam       NaN         NaN   NaN
#
#         Variance         AT         RH          SR          BP  PPAccum  \
# 0            NaN        NaN        NaN         NaN         NaN      NaN
# 1            NaN        NaN        NaN         NaN         NaN      NaN
# 2            NaN        NaN        NaN         NaN         NaN      NaN
# 3            NaN        NaN        NaN         NaN         NaN      NaN
# 4            NaN        NaN        NaN         NaN         NaN      NaN
# ...          ...        ...        ...         ...         ...      ...
# 202192       NaN        NaN  17.871263  192.898000  757.183158      NaN
# 202193       NaN  36.660000  18.252632  161.242105         NaN      NaN
# 202194       NaN  33.582105  23.600000   80.157895  745.378947      NaN
# 202195       NaN  37.019178  55.307671  228.706154  749.476301      NaN
# 202196       NaN  30.226596  73.127660  163.893617  745.968085      NaN
#
#         Power        PM10       PM2_5         NO         NO2        NOx  \
# 0         NaN         NaN         NaN        NaN         NaN        NaN
# 1         NaN         NaN         NaN        NaN         NaN        NaN
# 2         NaN         NaN         NaN        NaN         NaN        NaN
# 3         NaN         NaN         NaN        NaN         NaN        NaN
# 4         NaN         NaN         NaN        NaN         NaN        NaN
# ...       ...         ...         ...        ...         ...        ...
# 202192    NaN   87.814737   34.304255  13.917158   19.854526  33.771684
# 202193    NaN  147.452632   40.126316        NaN    8.891011   5.250562
# 202194    NaN  331.126761  131.732394  51.202360  104.323370  74.652174
# 202195    NaN   50.119577   20.220000   6.365139   14.738356  21.004658
# 202196    NaN   52.734043   13.709302   8.764835   16.689011  15.998901
#
#               CO  CO2      Ozone  BlackCarbon   Benzene   Toluene  \
# 0            NaN  NaN        NaN          NaN       NaN       NaN
# 1            NaN  NaN        NaN          NaN       NaN       NaN
# 2            NaN  NaN        NaN          NaN       NaN       NaN
# 3            NaN  NaN        NaN          NaN       NaN       NaN
# 4            NaN  NaN        NaN          NaN       NaN       NaN
# ...          ...  ...        ...          ...       ...       ...
# 202192  0.734835  NaN  38.070213          NaN  1.563936       NaN
# 202193  0.819535  NaN  78.206522          NaN  0.000000  0.620000
# 202194  0.860652  NaN  76.047692          NaN       NaN       NaN
# 202195       NaN  NaN        NaN          NaN  0.996849  1.870137
# 202196  0.617912  NaN  10.763218          NaN  1.097872  2.794681
#
#         Eth-Benzene    Xylene  CH4  NMHC       VWS  THC        NH3        SO2  \
# 0               NaN       NaN  NaN   NaN       NaN  NaN        NaN        NaN
# 1               NaN       NaN  NaN   NaN       NaN  NaN        NaN        NaN
# 2               NaN       NaN  NaN   NaN       NaN  NaN        NaN        NaN
# 3               NaN       NaN  NaN   NaN       NaN  NaN        NaN        NaN
# 4               NaN       NaN  NaN   NaN       NaN  NaN        NaN        NaN
# ...             ...       ...  ...   ...       ...  ...        ...        ...
# 202192     4.092842       NaN  NaN   NaN       NaN  NaN  12.120947  12.064725
# 202193     0.000000       NaN  NaN   NaN       NaN  NaN  19.031461   8.647059
# 202194          NaN       NaN  NaN   NaN -0.522105  NaN        NaN  37.748652
# 202195     0.057397       NaN  NaN   NaN  5.000000  NaN   5.329589   6.234658
# 202196          NaN  0.318085  NaN   NaN  0.050000  NaN  38.931111   5.094444
#
#              Temp  MP-Xylene   RF  RackTemp  P_Xylene  O Xylene  ETH  SPM  AP  \
# 0             NaN        NaN  NaN       NaN       NaN       NaN  NaN  NaN NaN
# 1             NaN        NaN  NaN       NaN       NaN       NaN  NaN  NaN NaN
# 2             NaN        NaN  NaN       NaN       NaN       NaN  NaN  NaN NaN
# 3             NaN        NaN  NaN       NaN       NaN       NaN  NaN  NaN NaN
# 4             NaN        NaN  NaN       NaN       NaN       NaN  NaN  NaN NaN
# ...           ...        ...  ...       ...       ...       ...  ...  ...  ..
# 202192  33.071053   1.188842  0.0       NaN       NaN  3.700211  NaN  NaN NaN
# 202193  31.801075        NaN  0.0       NaN       NaN       NaN  NaN  NaN NaN
# 202194        NaN        NaN  NaN       NaN       NaN       NaN  NaN  NaN NaN
# 202195        NaN   0.734110  0.0       NaN       NaN  1.899589  NaN  NaN NaN
# 202196        NaN        NaN  0.0       NaN       NaN       NaN  NaN  NaN NaN
#
#         MH  readings_in_day  total_stations  active_stations           state
# 0      NaN              0.0               1                0   Uttar Pradesh
# 1      NaN              0.0               1                0         Gujarat
# 2      NaN              0.0               1                0         Haryana
# 3      NaN              0.0               1                0         Gujarat
# 4      NaN              0.0               1                0         Haryana
# ...     ..              ...             ...              ...             ...
# 202192 NaN             94.0               1                1       Rajasthan
# 202193 NaN             95.0               1                1  Madhya Pradesh
# 202194 NaN             71.0               1                1   Uttar Pradesh
# 202195 NaN             67.0               1                1  Andhra Pradesh
# 202196 NaN             86.0               1                1  Andhra Pradesh
#
# [202197 rows x 46 columns]

# %%
df_ip = df_daily_city
city_state_dict = dict(zip(df_ip["city"].values,df_ip["state"].values))
len(city_state_dict), city_state_dict
# Out:
# (101,
#  {'Agra': 'Uttar Pradesh',
#   'Ahmedabad': 'Gujarat',
#   'Ambala ': 'Haryana',
#   'Ankleshwar': 'Gujarat',
#   'Bahadurgarh ': 'Haryana',
#   'Ballabgarh': 'Haryana',
#   'Bengaluru': 'Karnataka',
#   'Bhiwani': 'Haryana',
#   'Chennai': 'Tamil Nadu',
#   'Damoh': 'Madhya Pradesh',
#   'Delhi': 'Delhi',
#   'Dharuhera': 'Haryana',
#   'Faridabad': 'Haryana',
#   'Fatehabad ': 'Haryana',
#   'Gandhinagar': 'Gujarat',
#   'Ghaziabad': 'Uttar Pradesh',
#   'Gurugram': 'Haryana',
#   'Guwahati': 'Assam',
#   'Hapur': 'Uttar Pradesh',
#   'Hisar': 'Haryana',
#   'Hyderabad': 'Telangana',
#   'Jind': 'Haryana',
#   'Kaithal': 'Haryana',
#   'Kanpur': 'Uttar Pradesh',
#   'Karnal': 'Haryana',
#   'Kurukshetra ': 'Haryana',
#   'Loni Dehat': 'Uttar Pradesh',
#   'Lucknow': 'Uttar Pradesh',
#   'Maihar': 'Madhya Pradesh',
#   'Mandikhera': 'Haryana',
#   'Manesar ': 'Haryana',
#   'Mumbai': 'Maharashtra',
#   'Nagpur': 'Maharashtra',
#   'Narnaul': 'Haryana',
#   'Navi Mumbai': 'Maharashtra',
#   'Palwal ': 'Haryana',
#   'Panipat': 'Haryana',
#   'Pune': 'Maharashtra',
#   'Ratlam': 'Madhya Pradesh',
#   'Sirsa ': 'Haryana',
#   'Solapur': 'Maharashtra',
#   'Sonipat': 'Haryana',
#   'Vapi': 'Gujarat',
#   'Varanasi': 'Uttar Pradesh',
#   'Vatva': 'Gujarat',
#   'Yamuna Nagar': 'Haryana',
#   'Noida': 'Uttar Pradesh',
#   'Patna': 'Bihar',
#   'Chandrapur': 'Maharashtra',
#   'Gaya': 'Bihar',
#   'Haldia': 'West Bengal',
#   'Howrah': 'West Bengal',
#   'Kolkata': 'West Bengal',
#   'Muzaffarpur': 'Bihar',
#   'Durgapur': 'West Bengal',
#   'Jodhpur': 'Rajasthan',
#   'Nashik': 'Maharashtra',
#   'Rohtak': 'Haryana',
#   'Thane': 'Maharashtra',
#   'Tirupati': 'Andhra Pradesh',
#   'Visakhapatnam': 'Andhra Pradesh',
#   ' Alwar': 'Rajasthan',
#   'Ajmer': 'Rajasthan',
#   'Amaravati': 'Andhra Pradesh',
#   'Amritsar': 'Punjab',
#   'Aurangabad': 'Maharashtra',
#   'Bhiwadi': 'Rajasthan',
#   'Brajrajnagar': 'Odisha',
#   'Dewas': 'Madhya Pradesh',
#   'Jaipur': 'Rajasthan',
#   'Jorapokhar': 'Jharkhand',
#   'Kota': 'Rajasthan',
#   'Ludhiana': 'Punjab',
#   'Mandi Gobindgarh': 'Punjab',
#   'Moradabad': 'Uttar Pradesh',
#   'Pali': 'Rajasthan',
#   'Panchkula': 'Haryana',
#   'Pithampur': 'Madhya Pradesh',
#   'Rajamahendravaram': 'Andhra Pradesh',
#   'Singrauli': 'Madhya Pradesh',
#   'Talcher': 'Odisha',
#   'Thiruvananthapuram': 'Kerala',
#   'Udaipur': 'Rajasthan',
#   'Ujjain': 'Madhya Pradesh',
#   'Vijayawada': 'Andhra Pradesh',
#   'Asansol': 'West Bengal',
#   'Baghpat': 'Uttar Pradesh',
#   'Bathinda ': 'Punjab',
#   'Bulandshahr': 'Uttar Pradesh',
#   'Chikkaballapur': 'Karnataka',
#   'Greater Noida': 'Uttar Pradesh',
#   'Hubballi': 'Karnataka',
#   'Jalandhar': 'Punjab',
#   'Kalaburagi': 'Karnataka',
#   'Khanna': 'Punjab',
#   'Mandideep': 'Madhya Pradesh',
#   'Muzaffarnagar': 'Uttar Pradesh',
#   'Patiala': 'Punjab',
#   'Rupnagar': 'Punjab',
#   'Satna': 'Madhya Pradesh',
#   'Siliguri': 'West Bengal'})

# %%
#load OpenAQ data 2019-2021
root_path = "../PMdataset/"
df_daily_city_stn_oq = pd.read_csv(root_path+"pm2.5_allcities_groupby_date_city_station_2019_21_openaq.csv",index_col=0)
df_daily_city_oq = pd.read_csv(root_path+"pm2.5_allcities_groupby_date_city_2019_21_openaq.csv",index_col=0)
#df_daily_city_oq = df_daily_city_oq.groupby(["From Date","city"]).mean().reset_index()
df_daily_city_oq
# Out:
#         From Date       city       PM2_5  readings  total_stations  \
# 0      2019-01-18      Delhi  133.960000       2.0               1
# 2      2019-04-30       Agra   90.000000       1.0               1
# 3      2019-04-30      Ajmer  105.640000       2.0               1
# 4      2019-04-30  Amaravati   22.000000       1.0               1
# 6      2019-04-30   Amritsar   50.970000       1.0               1
# ...           ...        ...         ...       ...             ...
# 75127  2021-08-01    Solapur   18.020000      69.0               1
# 75128  2021-12-03    Solapur         NaN       0.0               1
# 75129  2021-12-04    Solapur         NaN       0.0               1
# 75130  2021-12-05    Solapur   14.172069      29.0               1
# 75131  2025-06-14       Pune    6.000000    1951.0               1
#
#        active_stations
# 0                    1
# 2                    1
# 3                    1
# 4                    1
# 6                    1
# ...                ...
# 75127                1
# 75128                0
# 75129                0
# 75130                1
# 75131                1
#
# [51927 rows x 6 columns]

# %%
#merge cpcb and openaq 
df_daily_city_merged = pd.concat([df_daily_city,df_daily_city_oq])[["From Date","city",
                                                                    "PM2_5","total_stations","active_stations","state"]]

df_daily_city_merged.city = df_daily_city_merged.city.apply(lambda x:x.strip().lower())
df_daily_city_merged["From Date"] = pd.to_datetime(df_daily_city_merged["From Date"])
df_daily_city_merged = df_daily_city_merged.groupby(["From Date","city"]).mean().reset_index()
df_daily_city_merged
# Out:
#         From Date         city      PM2_5  total_stations  active_stations
# 0      2010-01-01         agra        NaN             1.0              0.0
# 1      2010-01-01    ahmedabad        NaN             1.0              0.0
# 2      2010-01-01       ambala        NaN             1.0              0.0
# 3      2010-01-01   ankleshwar        NaN             1.0              0.0
# 4      2010-01-01  bahadurgarh        NaN             1.0              0.0
# ...           ...          ...        ...             ...              ...
# 254058 2021-08-01      solapur  18.020000             1.0              1.0
# 254059 2021-12-03      solapur        NaN             1.0              0.0
# 254060 2021-12-04      solapur        NaN             1.0              0.0
# 254061 2021-12-05      solapur  14.172069             1.0              1.0
# 254062 2025-06-14         pune   6.000000             1.0              1.0
#
# [254063 rows x 5 columns]

# %%
df_daily_city_merged["state"] = df_daily_city_merged["city"].apply(lambda x:city_state_dict[x.capitalize()].lower() if x.capitalize() in city_state_dict else np.nan)
df_daily_city_merged
# Out:
#         From Date         city      PM2_5  total_stations  active_stations  \
# 0      2010-01-01         agra        NaN             1.0              0.0
# 1      2010-01-01    ahmedabad        NaN             1.0              0.0
# 2      2010-01-01       ambala        NaN             1.0              0.0
# 3      2010-01-01   ankleshwar        NaN             1.0              0.0
# 4      2010-01-01  bahadurgarh        NaN             1.0              0.0
# ...           ...          ...        ...             ...              ...
# 254058 2021-08-01      solapur  18.020000             1.0              1.0
# 254059 2021-12-03      solapur        NaN             1.0              0.0
# 254060 2021-12-04      solapur        NaN             1.0              0.0
# 254061 2021-12-05      solapur  14.172069             1.0              1.0
# 254062 2025-06-14         pune   6.000000             1.0              1.0
#
#                 state
# 0       uttar pradesh
# 1             gujarat
# 2                 NaN
# 3             gujarat
# 4                 NaN
# ...               ...
# 254058    maharashtra
# 254059    maharashtra
# 254060    maharashtra
# 254061    maharashtra
# 254062    maharashtra
#
# [254063 rows x 6 columns]

# %%
df_daily_city_merged.state.unique()
# Out:
# array(['uttar pradesh', 'gujarat', nan, 'haryana', 'karnataka',
#        'tamil nadu', 'madhya pradesh', 'delhi', 'assam', 'telangana',
#        'maharashtra', 'bihar', 'west bengal', 'rajasthan',
#        'andhra pradesh', 'punjab', 'odisha', 'jharkhand', 'kerala'],
#       dtype=object)

# %% [markdown]
# # create table for PM2.5 & articles for cities

# %%
#check city wise data start date & end date
def get_start_date(city,threshold = 0.8,n = 365):
    print(city)
    test = df_daily_city_merged[df_daily_city_merged.city == city]
    test["From Date"] = pd.to_datetime(test["From Date"])
    test_drop_na = test.dropna(subset=["PM2_5"])

    for idx,row in test_drop_na.iterrows():
        curr_date = row["From Date"]
        n = 365
        end_date = curr_date+pd.Timedelta(days=n)
        date_range = pd.date_range(curr_date,end_date)
        temp = test[test["From Date"].isin(date_range)]
        frac = len(temp.dropna(subset=["PM2_5"]))/len(temp)
        #print(frac)
        threshold = 0.8
        if frac >threshold:
            print(curr_date)
            return curr_date
def get_unique_cities_from_df(df,col="city"):
    '''
    returns dataframe of city->articles from dataframe
    as city can be list so unique() will not work
    '''
    unq = {}
    for each in df[col].values:
        if type(each) == str:
            cities = [each]
        elif type(each) == list:
            cities = each
        else:
            continue
        for city in cities:
            try:
                unq[city]+=1
            except:
                unq[city] = 1
    df = pd.DataFrame(unq.items(),columns = ["city","articles"]).sort_values("articles",ascending=False)
    return df

# %%
cdf = get_unique_cities_from_df(df_articles)
igp_cities = ["delhi","agra","lucknow","patna","kanpur","varanasi","noida","gurugram","faridabad","kolkata","amritsar"]
most_discussed_cities = list(cdf.nlargest(11,"articles")["city"].values) #most 11 discussed cities in news-media
needed_cities = list(set(igp_cities + most_discussed_cities)) #most
print(len(needed_cities),needed_cities)




#needed_cities = h.get_unique_cities_from_df(df_articles).nlargest(15,"articles")["city"].values

start_date = datetime(2010,1,1)
end_date = datetime(2021,6,1)

#df_cross_cities = df_daily_city_merged[(df_daily_city_merged["From Date"] >= start_date) & (df_daily_city_merged["From Date"] <= end_date)]
df_cross_cities = df_daily_city_merged.copy()
df_cross_cities = df_cross_cities[df_cross_cities.city.isin(needed_cities)]
dfs = []
for city in needed_cities:
    try:
        start_date = get_start_date(city)
        df = df_cross_cities[(df_cross_cities["city"] == city) & (df_cross_cities["From Date"]>start_date)]
        dfs.append(df)
    except Exception as e:
        print(city,e)
    
df_cross_cities = pd.concat(dfs)
df_cross_cities = pd.crosstab(index=df_cross_cities["From Date"],
                              columns=df_cross_cities.city,values=df_cross_cities["PM2_5"],aggfunc=lambda x:x)
df_cross_cities
# Out:
# 18 ['patna', 'faridabad', 'delhi', 'agra', 'varanasi', 'gurugram', 'nagpur', 'mumbai', 'hyderabad', 'noida', 'chennai', 'bengaluru', 'chandigarh', 'amritsar', 'kanpur', 'kolkata', 'lucknow', 'pune']
# patna
# 2015-10-01 00:00:00
# faridabad
# 2015-05-20 00:00:00
# delhi
# 2010-02-17 00:00:00
# agra
# 2015-05-11 00:00:00
# varanasi
# 2014-09-13 00:00:00
# gurugram
# 2016-01-22 00:00:00
# nagpur
# 2011-05-04 00:00:00
# mumbai
# 2014-09-05 00:00:00
# hyderabad
# 2015-03-31 00:00:00
# noida
# 2017-07-17 00:00:00
# chennai
# 2015-03-23 00:00:00
# bengaluru
# 2015-03-20 00:00:00
# chandigarh
# chandigarh Invalid comparison between dtype=datetime64[ns] and NoneType
# amritsar
# 2017-02-27 00:00:00
# kanpur
# 2015-05-12 00:00:00
# kolkata
# 2018-04-10 00:00:00
# lucknow
# 2015-03-18 00:00:00
# pune
# 2015-06-06 00:00:00
# city             agra  amritsar  bengaluru    chennai       delhi  faridabad  \
# From Date
# 2010-02-18        NaN       NaN        NaN        NaN  135.687500        NaN
# 2010-02-19        NaN       NaN        NaN        NaN  107.047158        NaN
# 2010-02-20        NaN       NaN        NaN        NaN   15.914687        NaN
# 2010-02-21        NaN       NaN        NaN        NaN    9.360000        NaN
# 2010-02-22        NaN       NaN        NaN        NaN   17.640370        NaN
# ...               ...       ...        ...        ...         ...        ...
# 2021-06-18  23.200000       NaN        NaN  19.718750   16.128846      40.66
# 2021-06-19  10.000000    53.615  39.696667  45.333423   30.945804      31.00
# 2021-06-20  24.850000       NaN  29.202500  31.232143   23.494222        NaN
# 2021-06-21  19.866667       NaN  18.820000  30.535714   41.096285        NaN
# 2025-06-14        NaN       NaN        NaN        NaN         NaN        NaN
#
# city        gurugram  hyderabad  kanpur    kolkata  lucknow     mumbai  \
# From Date
# 2010-02-18       NaN        NaN     NaN        NaN      NaN        NaN
# 2010-02-19       NaN        NaN     NaN        NaN      NaN        NaN
# 2010-02-20       NaN        NaN     NaN        NaN      NaN        NaN
# 2010-02-21       NaN        NaN     NaN        NaN      NaN        NaN
# 2010-02-22       NaN        NaN     NaN        NaN      NaN        NaN
# ...              ...        ...     ...        ...      ...        ...
# 2021-06-18       NaN  17.647059     4.7  19.250000     8.18  35.372941
# 2021-06-19      39.6  10.564039    25.0  29.350000    21.96  23.340465
# 2021-06-20      31.0  22.000000     NaN  29.540984      NaN  43.978077
# 2021-06-21      49.5  47.013889    35.5  40.250000    12.90  51.575455
# 2025-06-14       NaN        NaN     NaN        NaN      NaN        NaN
#
# city        nagpur      noida  patna    pune  varanasi
# From Date
# 2010-02-18     NaN        NaN    NaN     NaN       NaN
# 2010-02-19     NaN        NaN    NaN     NaN       NaN
# 2010-02-20     NaN        NaN    NaN     NaN       NaN
# 2010-02-21     NaN        NaN    NaN     NaN       NaN
# 2010-02-22     NaN        NaN    NaN     NaN       NaN
# ...            ...        ...    ...     ...       ...
# 2021-06-18     NaN        NaN    NaN  10.020       NaN
# 2021-06-19   33.25  18.355000    NaN  13.800     20.00
# 2021-06-20     NaN  15.835000    NaN     NaN       NaN
# 2021-06-21     NaN  31.658095    NaN  63.818     16.78
# 2025-06-14     NaN        NaN    NaN   6.000       NaN
#
# [4101 rows x 17 columns]

# %% [markdown]
# ## Comparing with WHO & India standard

# %%
#from helper import geo_cities
import pickle
geo_cities = pickle.load(open("allcities_geo_params","rb")) #used to get district and state from city used by 

n = len(df_cross_cities)
df_table = pd.DataFrame()
df_table["India limit"] = df_cross_cities.apply(lambda x: f"{int(100*sum(x.dropna()>60)/len(x.dropna()))}\%")
n = len(df_cross_cities)
df_table["WHO limit"] = df_cross_cities.apply(lambda x: f"{int(100*sum(x.dropna()>25)/len(x.dropna()))}\%")
df_table= df_table.reset_index()


#df_articles = h.get_all_dataframe()
df_city_count = get_unique_cities_from_df(df_articles)

df_table = df_city_count.merge(df_table,left_on="city",right_on="city").sort_values("articles",ascending=False)
#df_table["city"] = df_table["city"].apply(lambda x:x.capitalize())
df_table
# Out:
#          city  articles India limit WHO limit
# 0       delhi      5285        81\%      98\%
# 1    gurugram       849        71\%      96\%
# 2      mumbai       647        25\%      64\%
# 3   bengaluru       537        11\%      64\%
# 4     kolkata       488        39\%      64\%
# 5     chennai       488        23\%      81\%
# 6      nagpur       471        20\%      58\%
# 7        pune       396        34\%      76\%
# 8   hyderabad       386        29\%      74\%
# 9       noida       368        66\%      94\%
# 10    lucknow       320        66\%      95\%
# 11      patna       317        69\%      95\%
# 12       agra        88        61\%      94\%
# 13     kanpur        56        63\%      93\%
# 14  faridabad        51        68\%      95\%
# 15   varanasi        51        69\%      92\%
# 16   amritsar        43        32\%      85\%

# %% [markdown]
# ## Get start & end date of readings for city

# %%
air_pollutant = "PM2_5"

end_date = datetime(2021,6,21)
data = []
#cities = df_daily_city_merged.city.unique()
#cities = igp_cities

#get top discussed cities
#cities_art = get_unique_cities_from_df(df_articles).nlargest(15,"articles")["city"]

#intersection of articles cities and pm2.5 availability cities
# cities_art = get_unique_cities_from_df(df_articles)["city"]
# cities_pm = df_daily_city_merged.city.unique()

# cities = set(cities_art).intersection(cities_pm)

cities = df_table["city"].values
not_found = []
print(len(cities),"cities")
for fname in cities:
    
    #df = pd.read_csv(all_cities_path+fname)
    fname = fname.lower()
    df = df_daily_city_merged[df_daily_city_merged.city == fname]
    
    
    try:
        df["From Date"] = pd.to_datetime(df["From Date"])
        
        start_date = get_start_date(fname)
        #start_date = datetime(2015,6,1)
        df = df[(df["From Date"]>=start_date) & (df["From Date"]<=end_date)] #subset
        #df = df[(df["From Date"]<=start_date) & (df["From Date"]>=end_date)] #strictly have start_date & end_date
        
        data.append({"city":df["city"].unique()[0],
                     "state":df["state"].unique()[0],

                    "PM2_5":int(round(df[air_pollutant].mean(),2)),
                    "start_date":df.dropna(subset=["PM2_5"])["From Date"].min().date(), #start date when first reading taken
                    "end_date":df.dropna(subset=["PM2_5"])["From Date"].max().date(), #end date when last reading taken
                    "active_days":len(df[~pd.isna(df[air_pollutant])])})
    except Exception as e:
        print(e)
        print(fname, "not found")
        not_found.append(fname)

df_avg_pm2_5 = pd.DataFrame(data)
df_avg_pm2_5.dropna(subset=["PM2_5"],inplace=True)
df_avg_pm2_5["address"] = df_avg_pm2_5.apply(lambda x:f"{x.city}, {x.state}",axis=1)
print(f"Before removing cities which have < 1year data- {len(df_avg_pm2_5)}")

df_avg_pm2_5 = df_avg_pm2_5[df_avg_pm2_5["active_days"]>365] #remove the cities which has data less than 1 year
df_avg_pm2_5
# Out:
# 17 cities
# delhi
# 2010-02-17 00:00:00
# gurugram
# 2016-01-22 00:00:00
# mumbai
# 2014-09-05 00:00:00
# bengaluru
# 2015-03-20 00:00:00
# kolkata
# 2018-04-10 00:00:00
# chennai
# 2015-03-23 00:00:00
# nagpur
# 2011-05-04 00:00:00
# pune
# 2015-06-06 00:00:00
# hyderabad
# 2015-03-31 00:00:00
# noida
# 2017-07-17 00:00:00
# lucknow
# 2015-03-18 00:00:00
# patna
# 2015-10-01 00:00:00
# agra
# 2015-05-11 00:00:00
# kanpur
# 2015-05-12 00:00:00
# faridabad
# 2015-05-20 00:00:00
# varanasi
# 2014-09-13 00:00:00
# amritsar
# 2017-02-27 00:00:00
# Before removing cities which have < 1year data- 17
#          city          state  PM2_5  start_date    end_date  active_days  \
# 0       delhi          delhi    142  2010-02-17  2021-06-21         4078
# 1    gurugram        haryana    116  2016-01-22  2021-06-21         1755
# 2      mumbai    maharashtra     49  2014-09-05  2021-06-21         2104
# 3   bengaluru      karnataka     36  2015-03-20  2021-06-21         2122
# 4     kolkata    west bengal     64  2018-04-10  2021-06-21         1080
# 5     chennai     tamil nadu     47  2015-03-23  2021-06-21         2234
# 6      nagpur    maharashtra     41  2011-05-04  2021-06-19         2843
# 7        pune    maharashtra     51  2015-06-06  2021-06-21         1719
# 8   hyderabad      telangana     47  2015-03-31  2021-06-21         2242
# 9       noida  uttar pradesh    114  2017-07-17  2021-06-21         1266
# 10    lucknow  uttar pradesh    111  2015-03-18  2021-06-21         2141
# 11      patna          bihar    119  2015-10-01  2021-06-08         1802
# 12       agra  uttar pradesh    103  2015-05-11  2021-06-21         2000
# 13     kanpur  uttar pradesh    113  2015-05-12  2021-06-21         2021
# 14  faridabad        haryana    120  2015-05-20  2021-06-19         2044
# 15   varanasi  uttar pradesh    114  2014-09-13  2021-06-21         2168
# 16   amritsar         punjab     57  2017-02-27  2021-06-19         1298
#
#                     address
# 0              delhi, delhi
# 1         gurugram, haryana
# 2       mumbai, maharashtra
# 3      bengaluru, karnataka
# 4      kolkata, west bengal
# 5       chennai, tamil nadu
# 6       nagpur, maharashtra
# 7         pune, maharashtra
# 8      hyderabad, telangana
# 9      noida, uttar pradesh
# 10   lucknow, uttar pradesh
# 11             patna, bihar
# 12      agra, uttar pradesh
# 13    kanpur, uttar pradesh
# 14       faridabad, haryana
# 15  varanasi, uttar pradesh
# 16         amritsar, punjab

# %% [markdown]
# ## Create Table showing WHO & India limit along with articles

# %%
df_table = df_table.merge(df_avg_pm2_5,left_on="city",right_on="city")[["city","PM2_5","India limit","WHO limit","articles","start_date","end_date"]]
df_table
# Out:
#          city  PM2_5 India limit WHO limit  articles  start_date    end_date
# 0       delhi    142        81\%      98\%      5285  2010-02-17  2021-06-21
# 1    gurugram    116        71\%      96\%       849  2016-01-22  2021-06-21
# 2      mumbai     49        25\%      64\%       647  2014-09-05  2021-06-21
# 3   bengaluru     36        11\%      64\%       537  2015-03-20  2021-06-21
# 4     kolkata     64        39\%      64\%       488  2018-04-10  2021-06-21
# 5     chennai     47        23\%      81\%       488  2015-03-23  2021-06-21
# 6      nagpur     41        20\%      58\%       471  2011-05-04  2021-06-19
# 7        pune     51        34\%      76\%       396  2015-06-06  2021-06-21
# 8   hyderabad     47        29\%      74\%       386  2015-03-31  2021-06-21
# 9       noida    114        66\%      94\%       368  2017-07-17  2021-06-21
# 10    lucknow    111        66\%      95\%       320  2015-03-18  2021-06-21
# 11      patna    119        69\%      95\%       317  2015-10-01  2021-06-08
# 12       agra    103        61\%      94\%        88  2015-05-11  2021-06-21
# 13     kanpur    113        63\%      93\%        56  2015-05-12  2021-06-21
# 14  faridabad    120        68\%      95\%        51  2015-05-20  2021-06-19
# 15   varanasi    114        69\%      92\%        51  2014-09-13  2021-06-21
# 16   amritsar     57        32\%      85\%        43  2017-02-27  2021-06-19

# %%
from datetime import datetime

def datetime_to_3charmonth_format(date):
    s = date
    # d = datetime.strptime(s, '%d %B, %Y')
    #mon,y = s.strftime('%B-%Y').split("-")
    #mon = mon.capitalize()[:3]
    
    mon,y = date.month, date.year
    y = str(y)[-2:]
    if mon <10:
        mon = str(mon)
    #print(mon,y)
    return f'{mon}/{y}'

df_table["Time-span"] = df_table.apply(lambda x: datetime_to_3charmonth_format(x.start_date)+" - "+ 
                                       datetime_to_3charmonth_format(x.end_date),axis=1) 

df_table["city"] = df_table["city"].apply(lambda x:x.capitalize())
df_table
# Out:
#          city  PM2_5 India limit WHO limit  articles  start_date    end_date  \
# 0       Delhi    142        81\%      98\%      5285  2010-02-17  2021-06-21
# 1    Gurugram    116        71\%      96\%       849  2016-01-22  2021-06-21
# 2      Mumbai     49        25\%      64\%       647  2014-09-05  2021-06-21
# 3   Bengaluru     36        11\%      64\%       537  2015-03-20  2021-06-21
# 4     Kolkata     64        39\%      64\%       488  2018-04-10  2021-06-21
# 5     Chennai     47        23\%      81\%       488  2015-03-23  2021-06-21
# 6      Nagpur     41        20\%      58\%       471  2011-05-04  2021-06-19
# 7        Pune     51        34\%      76\%       396  2015-06-06  2021-06-21
# 8   Hyderabad     47        29\%      74\%       386  2015-03-31  2021-06-21
# 9       Noida    114        66\%      94\%       368  2017-07-17  2021-06-21
# 10    Lucknow    111        66\%      95\%       320  2015-03-18  2021-06-21
# 11      Patna    119        69\%      95\%       317  2015-10-01  2021-06-08
# 12       Agra    103        61\%      94\%        88  2015-05-11  2021-06-21
# 13     Kanpur    113        63\%      93\%        56  2015-05-12  2021-06-21
# 14  Faridabad    120        68\%      95\%        51  2015-05-20  2021-06-19
# 15   Varanasi    114        69\%      92\%        51  2014-09-13  2021-06-21
# 16   Amritsar     57        32\%      85\%        43  2017-02-27  2021-06-19
#
#        Time-span
# 0    2/10 - 6/21
# 1    1/16 - 6/21
# 2    9/14 - 6/21
# 3    3/15 - 6/21
# 4    4/18 - 6/21
# 5    3/15 - 6/21
# 6    5/11 - 6/21
# 7    6/15 - 6/21
# 8    3/15 - 6/21
# 9    7/17 - 6/21
# 10   3/15 - 6/21
# 11  10/15 - 6/21
# 12   5/15 - 6/21
# 13   5/15 - 6/21
# 14   5/15 - 6/21
# 15   9/14 - 6/21
# 16   2/17 - 6/21

# %%
cols = ["city","PM2_5","India limit","WHO limit","articles","Time-span"]

df_final = df_table[cols]
df_final.insert(5, 'Articles', df_final.pop("articles"))
df_final.rename(columns={"city":"City",
                        "PM2_5":"Average PM$_{2.5}$ ($\mu g/m^3$)",
                        "Articles":"Articles(2010-21)",
                        "Time-span":"Time-span(PM$_{2.5}$)"},inplace=True)
df_final
# Out:
#          City  Average PM$_{2.5}$ ($\mu g/m^3$) India limit WHO limit  \
# 0       Delhi                               142        81\%      98\%
# 1    Gurugram                               116        71\%      96\%
# 2      Mumbai                                49        25\%      64\%
# 3   Bengaluru                                36        11\%      64\%
# 4     Kolkata                                64        39\%      64\%
# 5     Chennai                                47        23\%      81\%
# 6      Nagpur                                41        20\%      58\%
# 7        Pune                                51        34\%      76\%
# 8   Hyderabad                                47        29\%      74\%
# 9       Noida                               114        66\%      94\%
# 10    Lucknow                               111        66\%      95\%
# 11      Patna                               119        69\%      94\%
# 12       Agra                               103        61\%      94\%
# 13     Kanpur                               113        63\%      93\%
# 14  Faridabad                               120        68\%      95\%
# 15   Varanasi                               114        69\%      92\%
# 16   Amritsar                                57        32\%      85\%
#
#    Time-span(PM$_{2.5}$)  Articles(2010-21)
# 0            2/10 - 6/21               5285
# 1            1/16 - 6/21                849
# 2            9/14 - 6/21                647
# 3            3/15 - 6/21                537
# 4            4/18 - 6/21                488
# 5            3/15 - 6/21                488
# 6            5/11 - 6/21                471
# 7            6/15 - 6/21                396
# 8            3/15 - 6/21                386
# 9            7/17 - 6/21                368
# 10           3/15 - 6/21                320
# 11          10/15 - 6/21                317
# 12           5/15 - 6/21                 88
# 13           5/15 - 6/21                 56
# 14           5/15 - 6/21                 51
# 15           9/14 - 6/21                 51
# 16           2/17 - 6/21                 43

# %%
#df_final.to_csv("files/table_India_WHO_articles_IG_and_Discussed_cities.csv",index=False)
